# %% [markdown]
# # Test 1

# %%
from collections import Counter
from sklearn.cluster import KMeans
from matplotlib import colors
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
image = cv2.imread('f.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
def rgb_to_hex(rgb_color):
    hex_color = "#"
    for i in rgb_color:
        i = int(i)
        hex_color += ("{:02x}".format(i))
    return hex_color

# %%
def prep_image(raw_img):
    modified_img = cv2.resize(
        raw_img, (900, 600), interpolation=cv2.INTER_AREA)
    modified_img = modified_img.reshape(
        modified_img.shape[0]*modified_img.shape[1], 3)
    return modified_img

# %%
def color_analysis(img, number_color=5):
    clf = KMeans(n_clusters=number_color)
    color_labels = clf.fit_predict(img)
    center_colors = clf.cluster_centers_
    counts = Counter(color_labels)
    ordered_colors = [center_colors[i] for i in counts.keys()]
    hex_colors = [rgb_to_hex(ordered_colors[i]) for i in counts.keys()]
    ################################################################
    type(hex_colors)
    ################################################################
    plt.figure(figsize=(12, 8))
    # TODO: add color_labels=str(hex_colors) in plt.pie
    plt.pie(counts.values(), colors=hex_colors, autopct='%1.1f%%', startangle=90)
    plt.savefig("color_analysis_report.png")
    print(hex_colors)

# %%
modified_image = prep_image(image)
color_analysis(modified_image, number_color=5)
# Out:
# ['#191552', '#4f3975', '#f9e5e7', '#914c76', '#e0889a']

# %% [markdown]
# # Test 2
#
# Migliore

# %%
from collections import Counter
from sklearn.cluster import KMeans
from matplotlib import colors
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
image = cv2.imread('f.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
def RGB_HEX(color):
    return "#{:02x}{:02x}{:02x}".format(int(color[0]), int(color[1]), int(color[2]))

# %%
def get_colors(image, number_of_colors, show_chart):
    reshaped_image = cv2.resize(image, (600, 400))
    reshaped_image = reshaped_image.reshape(
        reshaped_image.shape[0]*reshaped_image.shape[1], 3)
    clf = KMeans(n_clusters=number_of_colors)
    labels = clf.fit_predict(reshaped_image)
    counts = Counter(labels)
    counts = dict(sorted(counts.items()))
    center_colors = clf.cluster_centers_
    ordered_colors = [center_colors[i] for i in counts.keys()]
    hex_colors = [RGB_HEX(ordered_colors[i]) for i in counts.keys()]
    rgb_colors = [ordered_colors[i] for i in counts.keys()]
    if (show_chart):
        plt.figure(figsize=(8, 6))
        plt.pie(counts.values(), labels=hex_colors, colors=hex_colors, autopct='%1.1f%%', startangle=45, counterclock=False)
        plt.show()
        ################################
        # add bar chart stacked ########
        ################################
        print(len(counts.values()))
        for i in range (0, len(counts.values())):
            plt.bar(labels="color", y=counts.values()[i], color=hex_colors[i])
            #plt.show()
    return rgb_colors

# %%
get_colors(image=image, number_of_colors=4, show_chart=True)
# Out:
# 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_24000/3339864993.py in <module>
# ----> 1 get_colors(image=image, number_of_colors=4, show_chart=True)
#
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_24000/1065565607.py in get_colors(image, number_of_colors, show_chart)
#      20         print(len(counts.values()))
#      21         for i in range (0, len(counts.values())):
# ---> 22             plt.bar(labels="color", y=counts.values()[i], color=hex_colors[i])
#      23             #plt.show()
#      24     return rgb_colors
#
# TypeError: 'dict_values' object is not subscriptable

# %% [markdown]
# # Test 3

# %%
from collections import Counter
from sklearn.cluster import KMeans
from matplotlib import colors
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
image = cv2.imread('f.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
def preprocess(raw):
    image = cv2.resize(raw, (900, 600), interpolation=cv2.INTER_AREA)
    image = image.reshape(image.shape[0]*image.shape[1], 3)
    return image

# %%
def rgb_to_hex(rgb_color):
    hex_color = "#"
    for i in rgb_color:
        hex_color += ("{:02x}".format(int(i)))
    return hex_color

# %%
def analyze(img):
    clf = KMeans(n_clusters = 5)
    color_labels = clf.fit_predict(img)
    center_colors = clf.cluster_centers_
    counts = Counter(color_labels)
    ordered_colors = [center_colors[i] for i in counts.keys()]
    hex_colors = [rgb_to_hex(ordered_colors[i]) for i in counts.keys()]

    plt.figure(figsize = (12, 8))
    plt.pie(counts.values(), labels = hex_colors, colors = hex_colors)

    plt.savefig("results.png")
    print("Found the following colors:\n")
    for color in hex_colors:
        print(color)

# %%
modified_image = preprocess(image)
analyze(modified_image)
# Out:
# Found the following colors:
#
# #191552
# #4f3975
# #f9e5e7
# #e0889a
# #914c76

# %% [markdown]
# # Mio

# %%
from collections import Counter
from sklearn.cluster import KMeans
from matplotlib import colors
import matplotlib.pyplot as plt
import numpy as np
import cv2
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
from webcolors import hex_to_name #name color

# %%
image = cv2.imread('g.jpg')
plt.imshow(image)

# %%
def RGB_HEX(color):
    return "#{:02x}{:02x}{:02x}".format(int(color[0]), int(color[1]), int(color[2]))

# %%
reshaped_image = cv2.resize(image, (600, 400))
reshaped_image = reshaped_image.reshape(reshaped_image.shape[0]*reshaped_image.shape[1], 3)
clf = KMeans(n_clusters=5)
labels = clf.fit_predict(reshaped_image)
counts = Counter(labels)# conta il numero di elementi in ogni cluster
#counts = dict(sorted(counts.items()))
center_colors = clf.cluster_centers_
ordered_colors = [center_colors[i] for i in counts.keys()]
hex_colors = [RGB_HEX(ordered_colors[i]) for i in counts.keys()]
rgb_colors = [ordered_colors[i] for i in counts.keys()]

# %%
print(counts)
print(hex_colors)
['#426537', '#57c8a7', '#4947bc', '#4e986a', '#dbeef5']
print(rgb_colors)
print(max(rgb_colors[0]) / 255)
print(max(rgb_colors[2]) / 255)
# Out:
# Counter({3: 150030, 0: 59837, 4: 16655, 1: 7606, 2: 5872})
# ['#0b1912', '#095891', '#128ce8', '#060908', '#103b32']
# [array([11.80887714, 25.50627153, 18.25500886]), array([  9.04403839,  88.30642829, 145.4411726 ]), array([ 18.24766117, 140.57152577, 232.21551284]), array([6.54578298, 9.82948615, 8.69111403]), array([16.86919806, 59.35359645, 50.31879978])]
# 0.10002459424416069
# 0.9106490699698807

# %%
for i in counts.keys():
    #webcolors.hex_to_name(hex_colors[i])
    try:
        requested_colour = rgb_colors[i]
        named_color = rgb_to_name((int(rgb_colors[i][0]), int(rgb_colors[i][1]), int(rgb_colors[i][2])))
        print(named_color)
    except ValueError:
        print("No name found")
# Out:
# No name found
# No name found
# No name found
# No name found
# No name found

# %%
counts=dict(sorted(counts.items(), key=lambda item: item[1]))
bottom=0
fig, ax = plt.subplots(figsize=(2, 8))
a=0
for i in counts.keys():
        ax.bar(x="color", height=counts[i]*100/sum(counts.values()),color=hex_colors[a], bottom=bottom)
        ax.yaxis.set_minor_locator(AutoMinorLocator())
        bottom += counts[i]*100/sum(counts.values())
        a+=1
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.axes.xaxis.set_visible(False)
#plt.gca().invert_yaxis()
plt.show()

# %%
plt.pie(counts.values(), labels=hex_colors, colors=hex_colors,
        autopct='%1.1f%%', startangle=45, counterclock=False)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5, 5))
patches, texts, autotexts = ax.pie(counts.values(), labels=hex_colors, colors=hex_colors,
        autopct='%1.1f%%', startangle=45, counterclock=False)
for i in counts.keys():
        if (max(rgb_colors[i]) / 255)<0.75: #imposto valore soglia oltre il quale l colore è troppo scuro e converto il testo in bianco
                autotexts[i].set_color('white')
plt.show()

# %%
import numpy as np
import webcolors as wc


def get_approx_color(hex_color):
    orig = wc.hex_to_rgb(hex_color)
    similarity = {}
    for hex_code, color_name in wc.CSS3_HEX_TO_NAMES.items():
        approx = wc.hex_to_rgb(hex_code)
        similarity[color_name] = sum(np.subtract(orig, approx) ** 2)
    return min(similarity, key=similarity.get)

def get_color_name(hex_color):
    try:
        return wc.hex_to_name(hex_color)
    except ValueError:
        return get_approx_color(hex_color)

# this is the RGB value you want to get the corresponding color name of
rgb = (100, 104, 195)
hex_ = wc.rgb_to_hex(tuple(rgb))
color_name_ = get_color_name(hex_)

print(color_name_)  # returns slateblue```
# Out:
# slateblue

# %%
for i in counts.keys():
    color_name_ = get_color_name(hex_colors[i])
    print(color_name_)
# Out:
# dodgerblue
# teal
# darkslategray
# black
# black
